# %% [markdown]
# # Problem Statement
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model which will help the bank marketing team to know which customer will buy the product.
#
# Task3:-Suggestions to the Bank market team to make  customers  buy the product.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
# data = pd.read_csv("C:\\Users\\Shaikh Anas\\Desktop\\DataScience\\projects\\Re_ Request for Individual Project Assignment\Portugus Bank\\Data\\bank-additional\\bank-additional-full.csv",sep=";")

# %%
data=pd.read_csv("bank-additional-full.csv",sep=";")

# %% [markdown]
# # Basic checks

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.y.value_counts()  #  imbalanced data set
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
data.y = data.y.map({'yes':1,'no':0})

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# # # Exploratory Data Analyses

# %%
# categerical data
cat_data = data[[  'job', 'marital', 'education',
                   'default', 'housing', 'loan',
                    'contact', 'month', 'day_of_week',
                    'poutcome', 'cons.price.idx',]]

# Numerical data
num_data = data[['age','duration','campaign','pdays','previous',
                 'emp.var.rate',"cons.conf.idx", "euribor3m", "nr.employed"]]

# %% [markdown]
# ## Bivariate Analyses

# %% [markdown]
# # checking relationship between target variable and other variales

# %% [markdown]
# ### sweetviz chart

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# * age is not in normal distribution
# * admin and blue-collor are almost contain 50% jobs.
# * 60% are married proples
# * 40 to 45% peoples are from university degree
# * more than 50% people have their own house and 40% dont have there own house
# * 62% peoples call by cellular

# %% [markdown]
# ## Categorical values

# %%
# target and cat data
plt.figure(figsize=(20,25),facecolor='white')
plotnumber = 1
for column in cat_data:
    if plotnumber<10:
        ax = plt.subplot(8,2,plotnumber)
        sns.countplot(x=cat_data[column].dropna(axis=0),hue=data.y)

        plt.xlabel(column,fontsize=20)
        plt.ylabel('y',fontsize=20,rotation=70)
        plt.xticks(fontsize=15,rotation=20)
        plt.yticks(fontsize=15)
        plotnumber+=1

plt.tight_layout()

# %% [markdown]
# * most students yes to buy the product
# * retired perosons more exited to buy the product
# * More single perosn say less not to buy the product as compare to married person
# * those person who have already loan are less person
# * Contact throught cellular give more customers
# * During the month of may very less people say 'yes' for loan
# * During the months of  'December' 'march' 'septmember' and 'october' chances of takeing loan is very high

# %% [markdown]
# ## Numerical  Feature

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber= 1
for column in num_data:
    if plotnumber<10:
        ax = plt.subplot(5,2,plotnumber)
        sns.countplot(x=num_data[column].dropna(axis=0),hue=data.y)

        plt.xlabel(column,fontsize=20)
        plt.ylabel('y',fontsize=20)
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=20)

        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# * more time you reach you will get response

# %% [markdown]
# # PreProcessing

# %% [markdown]
# ### Remove unique wrong calues

# %%
contac_index_num = [index for (index, item) in enumerate(data['contact']) if item == 38.0]
df = data.drop(data.index[[27713, 27757, 27780, 27800, 27802, 27805, 27808, 27810, 27811, 27812, 27813, 27814, 27815, 27816, 27817, 27818, 27826, 27837, 27838, 27844, 27851, 27875, 27879, 27902, 27930, 27950, 27951, 27963, 28220, 28221, 28312, 28456, 28504, 28530, 28540, 28586, 28619, 28732, 28773, 29225, 29263, 29498, 29625, 29668, 29682, 29973, 29977, 29981, 29987, 29990, 30000, 30004, 30006, 30072, 30078, 30079, 30088, 30103, 30110, 30133, 30171, 30214, 30225, 30227, 30241, 30334, 30335, 30390, 30430, 30460, 30589, 35833, 35848, 35856, 35878, 35973, 36183, 36285, 36311, 36383, 36384, 36816, 36998, 37136, 37137, 37170, 37186, 37190, 37192, 37193, 37195, 37206, 37207, 37213, 37219, 37227, 37235, 37237, 37239, 37257, 37260, 37316, 37341, 37355, 37371, 37403, 37454, 37455, 37472, 37479, 37493, 37505, 37509, 37512, 37525, 37532, 37545, 37568, 37570, 37586, 37597, 37601, 37602, 37604, 37635, 37661, 37675, 37679, 37690, 37692, 37715, 37716, 37735, 37736, 37743, 37756, 37765, 37769, 37775, 37784, 37818, 37819, 37820, 37825, 37826, 37861, 37868, 37870, 37873, 37905, 37920, 37935, 37946, 37951, 37952, 37954, 37958, 37997, 37999, 38005, 38007, 38019, 38020, 38022, 38032, 38033, 38045, 38052, 38054, 38060, 38065, 38071, 38074, 38081, 38088, 38125, 38127, 38129, 38136, 38144, 38145, 38166, 38169, 38175, 38178, 38179, 38183, 38184, 38191, 38192, 38193, 38195, 38206, 38229, 38241, 38246, 38247, 38252, 38253, 38254, 38255, 38260, 38279, 38281, 38286, 38288, 38314, 38316, 38322, 38326, 38358, 38399, 38408, 38410, 38415, 38430, 38452, 38455, 38471, 38486, 38487, 38488, 38505, 38514, 38517, 38518, 38536, 38548, 38549, 38556, 38557, 38577, 38580, 38582, 38587, 38600, 38635, 38643, 38656, 38676, 38697, 38700, 38703, 38707, 38714, 38722, 38726, 38735, 38740, 38744, 38751, 38783, 38810, 38824, 38825, 38831, 38846, 38876, 38878, 38880, 38892, 38901, 38909, 38921, 38924, 38936, 38942, 38943, 38944, 38946, 38953, 38960, 38967, 38968, 38984, 39001, 39011, 39017, 39025, 39032, 39038, 39041, 39042, 39043, 39049, 39052, 39055, 39058, 39061, 39062, 39093, 39115, 39124, 39133, 39184, 39186, 39190, 39204, 39261, 39264, 39275, 39319, 39331, 39332, 39342, 39348, 39360, 39377, 39402, 39410, 39411, 39415, 39420, 39422, 39444, 39452, 39466, 39471, 39472, 39473, 39474, 39475, 39476, 39477, 39478, 39479, 39480, 39486, 39487, 39488, 39489, 39493, 39495, 39498, 39504, 39508, 39520, 39522, 39577, 39578, 39601, 39614, 39625, 39639, 39650, 39655, 39662, 39676, 39678, 39682, 39692, 39719, 39722, 39724, 39730, 39734, 39737, 39740, 39752, 39762, 39766, 39768, 39786, 39795, 39847, 39890, 39892, 39896, 39923, 39947, 39971, 39974, 39975, 40001, 40045, 40050, 40060, 40076, 40078, 40080, 40081, 40085, 40114, 40117, 40119, 40129, 40142, 40149, 40162, 40163, 40194, 40195, 40196, 40197, 40201, 40218, 40219, 40220, 40224, 40262, 40273, 40277, 40289, 40291, 40300, 40312, 40331, 40344, 40356, 40393, 40400, 40405, 40414, 40421, 40437, 40445, 40450, 40458, 40468, 40469, 40470, 40477, 40481, 40484, 40488, 40529, 40546, 40554, 40562, 40568, 40575, 40577, 40592, 40611, 40621, 40624, 40631, 40636, 40638, 40639, 40651, 40667, 40669, 40686, 40702, 40703, 40714, 40716, 40718, 40727, 40748, 40756, 40879, 40886, 40915, 40921, 40933, 40950, 40951, 40965, 40966, 40969, 40982, 40983, 40986, 40996, 41004, 41183, 41187]
])

# %%
# Drop rows with any NaN values
df=df.dropna()
# print(drop_nan)
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# drop_nan_subset = df.dropna(subset=['loan'])
# drop_nan_subset

# %%
# df = df.dropna(subset=['loan'])
# print(df.isna().sum())

# %% [markdown]
# # Outliers handling

# %%
plt.figure(figsize=(20,25))
plotnumber = 1
for i in num_data:
    if plotnumber<10:
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(num_data[i])
        plt.xlabel(i,size=15)
        plt.ylabel('count',size=15)

        plotnumber+=1
plt.tight_layout()

# %%
df =pd.DataFrame(df)

# %%
Q1 = df['age'].quantile(0.25)
print('Q1 quarlitele ',Q1)
Q3 = df['age'].quantile(0.75)
print('Q3 quartile ',Q3)
# Out:
# Q1 quarlitele  32.0
# Q3 quartile  47.0

# %%
# finding IQR
iqr = Q3-Q1
print('iqr is ',iqr)
# Out:
# iqr is  15.0

# %%
# find upper limit and lower limit
lower = Q1-1.5*iqr
upper = Q3+1.5*iqr
print('lower limit is ',lower,'upper limit is ',upper)
# Out:
# lower limit is  9.5 upper limit is  69.5

# %%
# finding values above upper limit
df.loc[df['age']>upper]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# find the values below lower limit
df.loc[df['age']<lower]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
# finding percentage of outliers
# not more than 5%
print('upper',len(df.loc[data['age']>upper])/len(df))
print('lower',len(df.loc[data['age']<lower])/len(df))
# Out:
# upper 0.0
# lower 0.0

# %%
df.loc[df['age']>upper]=df['age'].median()

# %% [markdown]
# # feature engineering

# %% [markdown]
# #### One Hot Ecoding

# %%
df.job= df.job.map({'admin.':0,'blue-collar':1,'technician':2,'services':3,'management':4,'entrepreneur':5,'self-employed':6,
                        'retired':7,'housemaid':8,'unemployed':9,'student':10,"unknown":11})

# %%
df.marital = df.marital.map({'married':0,"single":1,"divorced":2,"unknown":3})

# %%
df.education = df.education.map({'university.degree':0,'high.school':1,'basic.9y':2,'professional.course':3,'basic.4y':4,
                                     'basic.6y':5,'unknown':6,'illiterate':7})

# %%
df.default = df.default.map({'no':0,'unknown':1,'yes':2})

# %%
df.housing = df.housing.map({'yes':0,'no':1,'unknown':3})

# %%
df.loan =df.loan.map({'no':0,'yes':1,'unknown':3})

# %%
df.contact =df.contact.map({'telephone':0,'cellular':1})

# %%
df.poutcome = df.poutcome.map({'nonexistent':0,'failure':1,'success':2})

# %%
# Import label encoder
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['month']= le.fit_transform(df['month'])
df['day_of_week']=le.fit_transform(df["day_of_week"])

# %%
# Changing Data type
df['month'] = df['month'].astype('int64')
df['day_of_week'] = df['day_of_week'].astype('int64')

# %%
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40719 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             40719 non-null  int64
#  1   job             40719 non-null  int64
#  2   marital         40719 non-null  int64
#  3   education       40719 non-null  int64
#  4   default         40719 non-null  int64
#  5   housing         40719 non-null  int64
#  6   loan            40719 non-null  int64
#  7   contact         40719 non-null  int64
#  8   month           40719 non-null  int64
#  9   day_of_week     40719 non-null  int64
#  10  duration        40719 non-null  int64
#  11  campaign        40719 non-null  int64
#  12  pdays           40719 non-null  int64
#  13  previous        40719 non-null  int64
#  14  poutcome        40719 non-null  int64
#  15  emp.var.rate    40719 non-null  float64
#  16  cons.price.idx  40719 non-null  float64
# ...

# %% [markdown]
# # Feature Selection

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':20},cmap="Blues")

ax.set_title('Correlation Heat Map', weight='bold', fontsize = 25)
# sns.set(font_scale=3)
plt.show()

# %%
# Droping Features
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.8
threshold = 0.8
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

# Drop features
df_reduced = df.drop(columns=to_drop)

print(f"Columns to drop: {to_drop}")
print("DataFrame after dropping highly correlated features:")
df_reduced
# Out:
# Columns to drop: ['poutcome', 'euribor3m', 'nr.employed']
# DataFrame after dropping highly correlated features:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    8        0          4        0        1     0        0      6
# 1       57    3        0          1        1        1     0        0      6
# 2       37    3        0          1        0        0     0        0      6
# 3       40    0        0          5        0        1     0        0      6
# 4       56    3        0          1        0        1     1        0      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181   37    0        0          0        0        0     0        1      7
# 41182   29    9        1          4        0        0     0        1      7
# 41184   46    1        0          3        0        1     0        1      7
# 41185   56    7        0          0        0        0     0        1      7
# ...

# %% [markdown]
# # Model Creation

# %%
from sklearn.model_selection import train_test_split

# %%
x=df_reduced.iloc[:,:-1]
y = df_reduced.y

# %%
x
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    8        0          4        0        1     0        0      6
# 1       57    3        0          1        1        1     0        0      6
# 2       37    3        0          1        0        0     0        0      6
# 3       40    0        0          5        0        1     0        0      6
# 4       56    3        0          1        0        1     1        0      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181   37    0        0          0        0        0     0        1      7
# 41182   29    9        1          4        0        0     0        1      7
# 41184   46    1        0          3        0        1     0        1      7
# 41185   56    7        0          0        0        0     0        1      7
# 41186   44    2        0          3        0        1     0        1      7
#
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42)

# %%
x_train
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 28155   26    0        0          1        0        1     0        1      0
# 23855   33    0        0          0        1        0     1        1      1
# 30807   40    0        1          1        0        1     0        1      6
# 23844   39    2        2          1        0        0     0        1      1
# 35208   42    0        0          2        1        0     0        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 6265    58    7        0          3        1        1     0        0      6
# 11284   37    4        0          0        0        1     0        0      4
# 38369   55    5        0          3        0        1     0        1      8
# 860     40    4        0          0        0        0     0        0      6
# 15795   29    0        1          0        0        0     0        1      3
#
# ...

# %%
# model building
from sklearn.linear_model import LogisticRegression

# %%
CLR  = LogisticRegression()
CLR
# Out:
# LogisticRegression()

# %%
CLR.fit(x_train,y_train) # traning
# Out:
# LogisticRegression()

# %%
y_predict = CLR.predict(x_test)

# %%
print(y_predict)
# Out:
# [0 0 0 ... 0 0 0]

# %%
y_predict_proba  = CLR.predict_proba(x_test)

# %% [markdown]
# # Evolvation Model

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,classification_report,f1_score,precision_recall_curve

# %%
cm = confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[8826,  240],
#        [ 724,  390]], dtype=int64)

# %%
accur = accuracy_score(y_test,y_predict)
accur
# Out:
# 0.9053045186640472

# %%
f1  = f1_score(y_test,y_predict)
f1
# Out:
# 0.4472477064220184

# %%
recall = recall_score(y_test,y_predict)
recall
# Out:
# 0.3500897666068223

# %%
precision = precision_score(y_test,y_predict)
precision
# Out:
# 0.6190476190476191

# %%
clas = classification_report(y_test,y_predict)
print(clas)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      9066
#            1       0.62      0.35      0.45      1114
#
#     accuracy                           0.91     10180
#    macro avg       0.77      0.66      0.70     10180
# weighted avg       0.89      0.91      0.89     10180

# %%
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE

# Oversample the minority class
smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x_train, y_train)

# %%
CLR.fit(x_resampled,y_resampled) # traning
y_predict = CLR.predict(x_test)
y_predict_proba  = CLR.predict_proba(x_test)

# %%
# Predict on the test set
y_probs = CLR.predict_proba(x_test)[:, 1]
threshold = 0.3
y_pred_threshold = (y_probs >= threshold).astype(int)

# Evaluate the model
print(confusion_matrix(y_test, y_pred_threshold))
print(classification_report(y_test, y_pred_threshold))

# Plot Precision-Recall Curve to find the optimal threshold
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# [[6982 2084]
#  [ 107 1007]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.86      9066
#            1       0.33      0.90      0.48      1114
#
#     accuracy                           0.78     10180
#    macro avg       0.66      0.84      0.67     10180
# weighted avg       0.91      0.78      0.82     10180

# %% [markdown]
# ### Trying with random forest classifier

# %%
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve

from sklearn.ensemble import RandomForestClassifier


# Train the model on resampled data
model = RandomForestClassifier(random_state=42)
model.fit(x_resampled, y_resampled)

# Predict on the test set
y_probs = model.predict_proba(x_test)[:, 1]
threshold = 0.3
y_pred_threshold = (y_probs >= threshold).astype(int)

# Evaluate the model
print(confusion_matrix(y_test, y_pred_threshold))
print(classification_report(y_test, y_pred_threshold))

# Plot Precision-Recall Curve to find the optimal threshold
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# [[8060 1006]
#  [ 171  943]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93      9066
#            1       0.48      0.85      0.62      1114
#
#     accuracy                           0.88     10180
#    macro avg       0.73      0.87      0.77     10180
# weighted avg       0.93      0.88      0.90     10180

# %%
import pickle
# open a file, where you ant to store the data
file = open('Portugus_Bank.pkl', 'wb')

# dump information to that file
pickle.dump(y_pred_threshold, file)

# %%
pki = pd.read_pickle('Portugus_Bank.pkl')
print(pki)
# Out:
# [0 0 0 ... 0 0 0]
